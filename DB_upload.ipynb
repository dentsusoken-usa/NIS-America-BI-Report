# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
df = pd.read_csv('DataSource/Output/marginal_profit_report.csv')
df.rename(columns={'Unnamed: 0': 'id'}, inplace=True)

# %%
username = 'nisaRetoolAdmin'
password = '!Retooladmin'
host = 'nisa-retool.mysql.database.azure.com'
port = '3306'
database_name = 'nisa'

connection_string = f"mysql+pymysql://{username}:{password}@{host}:{port}/{database_name}"
engine = create_engine(connection_string)

# %%
try:
    df.to_sql(
        name='marginal_profit_report',
        con=engine,
        if_exists='replace',
        index=False
    )
    print("Data successfully pushed to MySQL database!")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Data successfully pushed to MySQL database!
